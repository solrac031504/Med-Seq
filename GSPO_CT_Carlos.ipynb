# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/CAP_6614_current_topics_in_ML/GSPO
# Out:
# /content/drive/.shortcut-targets-by-id/14bcI5za8-JabHiOTgUuF4Pd2V7wT9t1l/GSPO

# %%
# !pip install -r src/requirements.txt
# Out:
# ...
#   Cloning https://github.com/openai/CLIP.git (to revision dcba3cb2e2827b402d2701e7e1c7d9fed8a20ef1) to /tmp/pip-install-in39m674/clip_586d4e830ee946f680d310e3d2e0d02a
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/CLIP.git /tmp/pip-install-in39m674/clip_586d4e830ee946f680d310e3d2e0d02a
#   Running command git rev-parse -q --verify 'sha^dcba3cb2e2827b402d2701e7e1c7d9fed8a20ef1'
#   Running command git fetch -q https://github.com/openai/CLIP.git dcba3cb2e2827b402d2701e7e1c7d9fed8a20ef1
#   Resolved https://github.com/openai/CLIP.git to commit dcba3cb2e2827b402d2701e7e1c7d9fed8a20ef1
#   Preparing metadata (setup.py) ... done
# ...
#   Cloning https://github.com/huggingface/lighteval.git (to revision 4f381b352c0e467b5870a97d41cb66b487a2c503) to /tmp/pip-install-in39m674/lighteval_95cbbb20fa944d7580cc29ad339783d6
# ...

# %%
# Download base model
from huggingface_hub import snapshot_download

snapshot_download(
    repo_id="Qwen/Qwen2-VL-2B-Instruct",
    local_dir="/content/drive/MyDrive/CAP_6614_current_topics_in_ML/GSPO/GSPO_checkpoints/Qwen2-VL-2B-Instruct"
)
# Out:
# Fetching 14 files:   0%|          | 0/14 [00:00<?, ?it/s]
# README.md: 0.00B [00:00, ?B/s]
# .gitattributes: 0.00B [00:00, ?B/s]
# chat_template.json: 0.00B [00:00, ?B/s]
# config.json: 0.00B [00:00, ?B/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/3.99G [00:00<?, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# generation_config.json:   0%|          | 0.00/272 [00:00<?, ?B/s]
# LICENSE: 0.00B [00:00, ?B/s]
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/347 [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/429M [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# '/content/drive/.shortcut-targets-by-id/14bcI5za8-JabHiOTgUuF4Pd2V7wT9t1l/GSPO/GSPO_checkpoints/Qwen2-VL-2B-Instruct'

# %%
# !torchrun --nproc_per_node=1 src/open_r1/gspo_vqa_nothink.py \
    --model_name_or_path /content/drive/MyDrive/CAP_6614_current_topics_in_ML/GSPO/GSPO_checkpoints/Qwen2-VL-2B-Instruct \
    --dataset_name /content/drive/MyDrive/CAP_6614_current_topics_in_ML/GSPO/Splits/train/CT(Computed Tomography)_train \
    --output_dir /content/drive/MyDrive/CAP_6614_current_topics_in_ML/GSPO/GSPO_outputs/ct_test_run \
    --per_device_train_batch_size 1 \
    --gradient_accumulation_steps 4 \
    --num_train_epochs 1 \
    --learning_rate 1e-6 \
    --fp16 True \
    --report_to none
